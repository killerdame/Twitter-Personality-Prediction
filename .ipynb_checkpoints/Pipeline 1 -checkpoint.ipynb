# %%
from pull_tweets import connect_to_mongo, get_twitter_client, get_all_tweets
from database import select_all_tweets
import twitter, yaml
import pymongo
import pandas as pd
from pymongo import MongoClient
import csv
import re
from nltk.tokenize import RegexpTokenizer
from nltk.stem import LancasterStemmer
from nltk.corpus import stopwords
from unidecode import unidecode
from lib.cleaning_module import clean_text
from nltk.tokenize import word_tokenize
import pickle

# %%
# connect_to_mongo()
# Out:
# [u'ellen', u'gina', u'tweets', u'elon', u'donald', u'russell', u'michael', u'noam', u'paolo', u'pers', u'oprah', u'katy', u'barack', u'kim']
# Database(MongoClient(host=['52.39.42.122:27017'], document_class=dict, tz_aware=False, connect=True), u'twitter')

# %%
# get_twitter_client()

# client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
# database = client_aws.twitter
# katy_coll = database.katy
# katy_cur = katy_coll.find()
# all_katy = list (katy_cur)
# katy_df = pd.DataFrame(all_katy)
# katy_df= katy_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]
# katy_df
# Out:
#                                                    text  \
# 0     🥀I never promised you a rose garden🥀 adamsel...
# 1     ✨#Versace...on the floor #thebrits2017 #chaine...
# 2     I’m on @musicallyapp! Show me your #CHAINEDTOT...
# 3     Tonight I'll be making it rain Yorkshire puddi...
# 4     #CHAINEDTOTHERHYTHM VIDEO IS OUT🤡 Peep the fe...
# 5     When you have so many surprises up your sleeve...
# 6                        @jcoopKP @R1Breakfast than* 😔
# 7     @jcoopKP @R1Breakfast better long toes that st...
# 8                  Yes brother! https://t.co/3aODTxD7rU
# 9     RT @itzmero: @katyperry #ChainedToTheRhythm KI...
# 10           Angela would never https://t.co/dWh1lQGSHW
# 11    RT @Vevo_UK: 🚨 The first video from @katyperr...
# 12    RT @katysprismlight: @katyperry my favourite m...
# 13            my protector 🙏🏻 https://t.co/7gB1gNULoe
# 14    RT @voguemagazine: Watch @KatyPerry's new musi...
# 15            omg am I cool yet https://t.co/psTFjRRuH9
# 16               Almost absurd! https://t.co/MzmKRLrx7U
# 17    WELCOME TO 🎢🎡🎠OBLIVIA🎠🎢🎡 WHERE EVERYTHIN...
# 18     COMING WITHIN HOUR(s)❗❗❗ https://t.co/OKwEfs8RO7
# 19         *whispers "action!"* https://t.co/KAhZEVLCDf
# 20    IF YOU REALLY LOVED ME IT WOULD BE "I LOVE YOU...
# 21    This was classic @miamoretti https://t.co/XXCu...
# 22    💣#CHAINEDTOTHERHYTHM💣VIDEO TOMORROW 2.21.17 ...
# 23    @Adriana_Franc0 it's ok it's a second listen r...
# 24    GIRL DO YOU/PAY NO MIND TO LE HATÉRS❗ https://...
# 25    GUYS WHEN WILL U BELIEVE ME FOR ONCE, I DONT L...
# 26    Y'all are my inspo, you get it. https://t.co/O...
# 27    💘GET VALIDATED ON LOVE ME💘VIDEO TUESDAY 2.21...
# 28    🔥#CHAINEDTOTHERHYTHM VIDEO TUESDAY 2.21.17🔥 ...
# 29    ⛓#CHAINEDTOTHERHYTHM VIDEO TUESDAY 2.21.17 ⛓ h...
# ...                                                 ...
# 3210  I heart you @Sarabareilles : http://t.co/6BGGz...
# 3211                             http://t.co/VicHI3Uhq4
# 3212  Thanks for letting me be the 5th wheel last ni...
# 3213  Mick &amp; Kate forever! @MickJagger http://t....
# 3214                                       I 💘 my mom!
# 3215  I noticed that. I guess I was too excited.  So...
# 3216  Yes, I just did gyrated on Mick Jagger. WHAT?!...
# 3217  Myyyy @maisonmichel moment! RT @MDMOLINARI: Th...
# 3218  I'm much obliged &amp; quite honored!RT @Rolli...
# 3219  Throw it👆throw it👆, that's how we 🏀 out. #i...
# 3220  Yaaaaass RT @yungskeeter: wish people would in...
# 3221         Jell-O shots at The Met ball is tres punk!
# 3222  Tonight for The Met I am channeling the OG que...
# 3223  Wow that picture posted upside down looks like...
# 3224                             http://t.co/73yljkMPHe
# 3225  Perfectly put by Labrinth feat. Emeli Sande: h...
# 3226  Sometimes it takes me weeks, months, years to ...
# 3227  Tonight's killer mani to match! http://t.co/nw...
# 3228  Just had an elegant unveiling of my new fragra...
# 3229  OK! I have been working on my 3rd fragrance fo...
# 3230  I have something very exciting to reveal to yo...
# 3231  AND if Billy Porter doesn't win the Tony for b...
# 3232  Just saw KINKY BOOTS on broadway &amp; cried w...
# 3233  Alternative Daft Punk lyric: We're up all nigh...
# 3234  Today my friend Tommy Hilfiger took me shoe sh...
# 3235                          PS http://t.co/wL5Epo8ybc
# 3236  Same! RT @diablocody: Congrats, Jason Collins,...
# 3237    RT @lenadunham: Twerkin hard or hardly twerkin?
# 3238                        Sup? http://t.co/U3KmFZyeyr
# 3239                        Sup? http://t.co/U3KmFZyeyr
#
#                                                    user
# 0     {u'follow_request_sent': False, u'has_extended...
# 1     {u'follow_request_sent': False, u'has_extended...
# 2     {u'follow_request_sent': False, u'has_extended...
# 3     {u'follow_request_sent': False, u'has_extended...
# 4     {u'follow_request_sent': False, u'has_extended...
# 5     {u'follow_request_sent': False, u'has_extended...
# 6     {u'follow_request_sent': False, u'has_extended...
# 7     {u'follow_request_sent': False, u'has_extended...
# 8     {u'follow_request_sent': False, u'has_extended...
# 9     {u'follow_request_sent': False, u'has_extended...
# 10    {u'follow_request_sent': False, u'has_extended...
# 11    {u'follow_request_sent': False, u'has_extended...
# 12    {u'follow_request_sent': False, u'has_extended...
# 13    {u'follow_request_sent': False, u'has_extended...
# 14    {u'follow_request_sent': False, u'has_extended...
# 15    {u'follow_request_sent': False, u'has_extended...
# 16    {u'follow_request_sent': False, u'has_extended...
# 17    {u'follow_request_sent': False, u'has_extended...
# 18    {u'follow_request_sent': False, u'has_extended...
# 19    {u'follow_request_sent': False, u'has_extended...
# 20    {u'follow_request_sent': False, u'has_extended...
# 21    {u'follow_request_sent': False, u'has_extended...
# 22    {u'follow_request_sent': False, u'has_extended...
# 23    {u'follow_request_sent': False, u'has_extended...
# 24    {u'follow_request_sent': False, u'has_extended...
# 25    {u'follow_request_sent': False, u'has_extended...
# 26    {u'follow_request_sent': False, u'has_extended...
# 27    {u'follow_request_sent': False, u'has_extended...
# 28    {u'follow_request_sent': False, u'has_extended...
# 29    {u'follow_request_sent': False, u'has_extended...
# ...                                                 ...
# 3210  {u'follow_request_sent': False, u'has_extended...
# 3211  {u'follow_request_sent': False, u'has_extended...
# 3212  {u'follow_request_sent': False, u'has_extended...
# 3213  {u'follow_request_sent': False, u'has_extended...
# 3214  {u'follow_request_sent': False, u'has_extended...
# 3215  {u'follow_request_sent': False, u'has_extended...
# 3216  {u'follow_request_sent': False, u'has_extended...
# 3217  {u'follow_request_sent': False, u'has_extended...
# 3218  {u'follow_request_sent': False, u'has_extended...
# 3219  {u'follow_request_sent': False, u'has_extended...
# 3220  {u'follow_request_sent': False, u'has_extended...
# 3221  {u'follow_request_sent': False, u'has_extended...
# 3222  {u'follow_request_sent': False, u'has_extended...
# 3223  {u'follow_request_sent': False, u'has_extended...
# 3224  {u'follow_request_sent': False, u'has_extended...
# 3225  {u'follow_request_sent': False, u'has_extended...
# 3226  {u'follow_request_sent': False, u'has_extended...
# 3227  {u'follow_request_sent': False, u'has_extended...
# 3228  {u'follow_request_sent': False, u'has_extended...
# 3229  {u'follow_request_sent': False, u'has_extended...
# 3230  {u'follow_request_sent': False, u'has_extended...
# 3231  {u'follow_request_sent': False, u'has_extended...
# 3232  {u'follow_request_sent': False, u'has_extended...
# 3233  {u'follow_request_sent': False, u'has_extended...
# 3234  {u'follow_request_sent': False, u'has_extended...
# 3235  {u'follow_request_sent': False, u'has_extended...
# 3236  {u'follow_request_sent': False, u'has_extended...
# 3237  {u'follow_request_sent': False, u'has_extended...
# 3238  {u'follow_request_sent': False, u'has_extended...
# 3239  {u'follow_request_sent': False, u'has_extended...
#
# [3240 rows x 2 columns]

# %%
with open('katy_df.pkl', 'w') as picklefile:
    pickle.dump(katy_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
barack_coll = database.barack
barack_cur = barack_coll.find()
all_barack = list (barack_cur)
barack_df = pd.DataFrame(all_barack)
barack_df = barack_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('barack_df.pkl', 'w') as picklefile:
    pickle.dump(barack_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
gina_coll = database.gina
gina_cur = gina_coll.find()
all_gina = list (gina_cur)
gina_df = pd.DataFrame(all_gina)
gina_df= gina_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('gina_df.pkl', 'w') as picklefile:
    pickle.dump(gina_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
paolo_coll = database.paolo
paolo_cur = paolo_coll.find()
all_paolo = list (paolo_cur)
paolo_df = pd.DataFrame(all_paolo)
paolo_df= paolo_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('paolo_df.pkl', 'w') as picklefile:
    pickle.dump(paolo_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
oprah_coll = database.oprah
oprah_cur = oprah_coll.find()
all_oprah = list (oprah_cur)
oprah_df = pd.DataFrame(all_oprah)
oprah_df= oprah_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('oprah_df.pkl', 'w') as picklefile:
    pickle.dump(oprah_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
michael_coll = database.michael
michael_cur = michael_coll.find()
all_michael = list (michael_cur)
michael_df = pd.DataFrame(all_michael)
michael_df= michael_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('michael_df.pkl', 'w') as picklefile:
    pickle.dump(michael_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
noam_coll = database.noam
noam_cur = noam_coll.find()
all_noam = list (noam_cur)
noam_df = pd.DataFrame(all_noam)
noam_df= noam_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('noam_df.pkl', 'w') as picklefile:
    pickle.dump(noam_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
kim_coll = database.kim 
kim_cur = kim_coll.find()
all_kim = list (kim_cur)
kim_df = pd.DataFrame(all_kim)
kim_df= kim_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('kim_df.pkl', 'w') as picklefile:
    pickle.dump(kim_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
ellen_coll = database.ellen 
ellen_cur = ellen_coll.find()
all_ellen = list (ellen_cur)
ellen_df = pd.DataFrame(all_ellen)
ellen_df= ellen_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('ellen_df.pkl', 'w') as picklefile:
    pickle.dump(ellen_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
donald_coll = database.donald 
donald_cur = donald_coll.find()
all_donald = list (donald_cur)
donald_df = pd.DataFrame(all_donald)
donald_df= donald_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('donald_df.pkl', 'w') as picklefile:
    pickle.dump(donald_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
elon_coll = database.elon 
elon_cur = elon_coll.find()
all_elon = list (elon_cur)
elon_df = pd.DataFrame(all_elon)
elon_df= elon_df[['text'.encode("utf-8"), 'user'.encode("utf-8")]]

# %%
with open('elon_df.pkl', 'w') as picklefile:
    pickle.dump(elon_df, picklefile)

# %%
client_aws = pymongo.MongoClient(host='52.39.42.122', port=27017)
database = client_aws.twitter
russell_coll = database.russell 
russell_cur = russell_coll.find()
all_russell = list (russell_cur)
russell_df = pd.DataFrame(all_russell)
russell_df= russell_df[['text'.encode("utf-8"), 'user']]

# %%
with open('russell_df.pkl', 'w') as picklefile:
    pickle.dump(russell_df, picklefile)

# %%
import json
russell_user_df = russell_df['user'].apply(lambda x: dict(x))
katy_user_df = katy_df['user'].apply(lambda x: dict(x))
barack_user_df = barack_df['user'].apply(lambda x: dict(x))
kim_user_df = kim_df['user'].apply(lambda x: dict(x))
elon_user_df = elon_df['user'].apply(lambda x: dict(x))
donald_user_df = donald_df['user'].apply(lambda x: dict(x))
oprah_user_df = oprah_df['user'].apply(lambda x: dict(x))
gina_user_df = gina_df['user'].apply(lambda x: dict(x))
michael_user_df = michael_df['user'].apply(lambda x: dict(x))
ellen_user_df = ellen_df['user'].apply(lambda x: dict(x))
noam_user_df = noam_df['user'].apply(lambda x: dict(x))
paolo_user_df = paolo_df['user'].apply(lambda x: dict(x))

# %%
def get_screen_name(x):
    return x['screen_name']

# %%
russell_df['user'] = russell_user_df[0]['screen_name']
katy_df['user'] = katy_user_df[0]['screen_name']
barack_df['user'] = barack_user_df[0]['screen_name']
kim_df['user'] = kim_user_df[0]['screen_name']
elon_df['user'] = elon_user_df[0]['screen_name']
donald_df['user'] = donald_user_df[0]['screen_name']
oprah_df['user'] = oprah_user_df[0]['screen_name']
gina_df['user'] = gina_user_df[0]['screen_name']
michael_df['user'] = michael_user_df[0]['screen_name']
ellen_df['user'] = ellen_user_df[0]['screen_name']
noam_df['user'] = noam_user_df[0]['screen_name']
paolo_df['user'] = paolo_user_df[0]['screen_name']

# %%
paolo_words = unidecode( ' '.join(paolo_df["text"].values))
paolo_words = re.sub(r"http\S+", "", paolo_words)
paolo_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>']", "", paolo_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(paolo_corpus.lower())
pc_filtered_text = [w for w in word_tokens if not w in stop_words]
print len(pc_filtered_text)
# Out:
# 27854

# %%
ellen_words = unidecode( ' '.join(ellen_df["text"].values))
ellen_words = re.sub(r"http\S+", "", ellen_words)
ellen_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", ellen_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize
snoopdogg', 'supposed', 'leave', '8', 'yung', 'hunnid', 'blow', 'away', 'littlebigshots', 'back', 'nbclilbigshots', 'happy', 'birthday', 'ice', 'theweeknd', 'much', 'talent', 'missing', 'letters', 'finallevel', 'matt', 'damon', 'told', 'spent', 'valentines', 'night', 'bunk', 'bed', 'theres', 'better', 'guest', 'office', 'bachelor', 'recap', 'show', 'nick', 'dont', 'know', 'viallnicholas28', 'blakeshelton', 'adamlevine', 'fakenews', 'hear', 'theyre', 'remake', '``', 'entourage', "''", 'low', 'shemika', 'go', 'really', 'really', 'reallllllllly', 'low', 'nyc', 'love', 'show', 'could', 'something', 'incredible', 'tell', 'adamlevine', 'tried', 'convince', 'loves', 'blake', 'say', 'love', 'use', 'caps', 'like', 'stephanie', 'loves', 'dancing', 'hunks', 'one', 'left', 'whole', 'lotta', 'singles', 'maroon5', 'performed', 'world', 'premiere', 'new', 'song', '``', 'cold', "''", 'right', 'show', 'prepare', 'marooned', 'best', 'little', 'bachelor', 'recap', 'thebachelor', 'ill', 'leave', 'right', 'va ...

# %%
bo_words = unidecode( ' '.join(barack_df["text"].values))
mm_words = unidecode( ' '.join(michael_df["text"].values))
ow_words = unidecode( ' '.join(oprah_df["text"].values))
em_words = unidecode( ' '.join(elon_df["text"].values))
kk_words = unidecode( ' '.join(kim_df["text"].values))
kp_words = unidecode( ' '.join(katy_df["text"].values))
nc_words = unidecode( ' '.join(noam_df["text"].values))

# %%
all_words = [rb_words, gr_words, dt_words, bo_words, mm_words, ow_words, em_words, kk_words, kp_words, nc_words]

# %%
rb_words = unidecode( ' '.join(russell_df["text"].values))
rb_words = re.sub(r"http\S+", "", rb_words)
rb_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", rb_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(rb_corpus.lower())
rb_filtered_text = [w for w in word_tokens if not w in stop_words]
print(rb_filtered_text)
# Out:
# ['true', 'lovewatch', 'full', 'video', 'new', 'trewswhat', 'true', 'lovewatch', 'thought', 'yep', 'find', 'higher', 'selfwatch', 'full', 'video', 'addiction', 'recovery', 'make', 'full', 'recovery', 'new', 'trewshow', 'find', 'higher', 'selfwatch', 'hey', 'lets', 'watch', 'baddiel', '4', 'tonight', 'yeah', 'yeah', 'mate', 'rosskemp', 'made', 'another', 'great', 'amazing', 'documentary', 'check', 'tomorrow', 'night', 'last', 'song', 'bears', 'op', 'rt', 'whatsoncork', 'russell', 'brand', 'rustyrockets', 'stand', 'tour', 'hes', 'heading', 'cork', '2018rebirth', '259', 'corkoperahouse', 'new', 'trewsis', 'monogamy', 'bestwatch', 'happy', 'valentines', 'day', 'boxing', 'day', 'amazing', 'personwhat', 'amazing', 'songwhats', 'going', 'themusicalslave', 'wan', 'na', 'sell', 'yer', 'ticket', 'sell', 'thanks', 'x', 'britains', 'finest', 'curry', 'maliks', 'delicious', 'food', 'served', 'gorgeous', 'people', 'new', 'trewswhy', 'mental', 'health', 'issues', 'increasing', 'watch', 'bear', 'escalator', 'rt', 'the_lowry', 'second', 'show', 'brilliant', 'rustyrockets', 'new', 'tour', 'rebirth', 'sale', 'tickets', 'hey', 'get', 'tickets', 'theyre', '
isgina', 'speaking', 'truth', 'lack', 'latinx', 'representation', 'tenemos', 'que', 'apoyar', 'nuestra', 'gente', 'ht', 'awesome', 'man', 'joe_locicero', 'choreographed', 'hahaha', 'might', 'one', 'takes', 'stop', 'slapping', 'many', 'times', 'getting', 'rea', 'rt', 'yaelgrobglas', 'oooooooo', 'would', 'wan', 'na', 'get', 'slapped', 'hereisgina', 'girl', 'strong', 'janethevirgin', 'girl', 'couldnt', 'agree', 'lift', 'latinos', 'continue', 'produce', 'work', 'shows', 'va', 'rt', 'cwjanethevirgin', 'get', 'ready', 'east', 'coast', 'new', 'episode', 'janethevirgin', 'coming', 'atcha', 'one', 'hour', 'rt', 'anthonyvo', 'jane', 'almost', 'cordend', 'dennis', 'janethevirgin', 'hereisgina', 'rt', 'cwjanethevirgin', 'oh', 'jane', 'use', 'words', 'janethevirgin', 'rt', 'cwjanethevirgin', 'yeahshe', 'really', 'seen', 'one', 'coming', 'janethevirgin', 'rt', 'sadbreakfast_', 'made', 'family', 'buy', 'dvf', 'well', 'done', 'hereisgina', 'rt', 'jaimendiola', 'janethevirgin', 'nails', 'first', 'episode', 'janes', 'devastating', 'heartbreak', 'hereisgina', 'rt', 'heresginas', 'waiting', 'hereisgina', 'invited', 'host', 'nbcsnl', 'rt', 'janeglorianas', 'jane', 'amp', 'michael', 'last', 'kisswatch', 'full', 'video', 'rt', 'cwjanethevirgin', 'jane', 'fights', 'grief', 'new', 'episode', 'janethevirgin', 'tomorrow', '98c', 'mira', 'que', 'fancy', 'consider', 'pop', 'itsgabrielleu', 'fam', 'representationmatters', 'majority', 'weekend', 'moviegoers', 'dont', 'get', ' ...

# %%
dt_words = unidecode( ' '.join(donald_df["text"].values))
dt_words = re.sub(r"http\S+", "", dt_words)
dt_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", dt_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(dt_corpus.lower())
dt_filtered_text = [w for w in word_tokens if not w in stop_words]
print(dt_filtered_text)
# Out:
# ['much', 'enjoyed', 'tour', 'smithsonians', 'national', 'museum', 'african', 'american', 'history', 'culturea', 'great', 'job', 'done', 'amazing', 'people', 'one', 'thing', 'say', 'rep', 'keith', 'ellison', 'fight', 'lead', 'dnc', 'one', 'predicted', 'early', 'would', 'win', 'socalled', 'angry', 'crowds', 'home', 'districts', 'republicans', 'actually', 'numerous', 'cases', 'planned', 'liberal', 'activists', 'sad', 'americans', 'overwhelmingly', 'oppose', 'sanctuary', 'cities', 'congratulations', 'new', 'national', 'security', 'advisor', 'general', 'hr', 'mcmaster', 'video', 'named', 'general', 'hr', 'mcmaster', 'national', 'security', 'advisor', 'happy', 'presidents', 'day', 'make', 'america', 'great', 'give', 'public', 'break', 'fake', 'news', 'media', 'trying', 'say', 'large', 'scale', 'immigration', 'sweden', 'working', 'beautifully', 'statement', 'whats', 'happening', 'sweden', 'reference', 'story', 'broadcast', 'foxnews', 'concerning', 'immigrants', 'amp', 'sweden', 'many', 'meetings', 'weekend', 'southern', 'white', 'house', 'big', '500', 'pm', 'speech', 'melbourne', 'florida', 'lot', 'talk', 'dont', 'believe', 'main', 'stream', 'fake', 'news', 'mediathe', 'white', 'house', 'running', 'well', 'inherited', 'mess', 'process', 'fixing', 'looking', 'forward', 'florida', 'rally', 'tomorrow', 'big', 'crowd', 'expected', '``', 'one', 'effective', 'press', 'conferences', 'ive', 'ever', 'seen', "''", 'says', 'rush', 'limbaugh', 'many', 'agreeyet', 'fake', 'media', 'calls', 'differently', 'dishonest', 'fake', 'news', 'media', 'failing', 'nytimes', 'nbcnews', 'abc', 'cbs', 'cnn', 'enemy', 'enemy', 'american', 'people', 'join', '1100amwatch', 'general', 'keith', 'kellogg', 'known', 'long', 'time', 'much', 'play', 'nsa', 'three', 'others', 'thank', 'nice', 'statements', 'press', 'conference', 'yesterday', 'rush', 'limbaugh', 'said', 'one', 'greatest', 'ever', 'fake', 'media', 'happy', 'going', 'charleston', 'south', 'carolina', 'order', 'spend', 'time', 'boeing', 'talk', 'jobs', 'look', 'forward', 'despite', 'long', 'delays', 'democrats', 'finally', 'approving', 'dr', 'tom', 'price', 'repeal', 'replacement', 'obamacare', 'moving', 'fast', 'trump', 'signs', 'bill', 'undoing', 'obama', 'coal', 'mining', 'rule', 'democrats', 'come', 'story', 'lost', 'election', 'badly', '306', 'made', 'story', 'russia', 'fake', 'news', 'fake', 'news', 'media', 'makes', 'stories', '``', 'sources', "''", 'far', 'effective', 'discredited', 'democrats', 'fading', 'fast', 'spotlight', 'finally', 'put', 'lowlife', 'leakers', 'caught', 'leaking', 'even', 'illegal', 'classified', 'leaking', 'big', 'problem', 'washington', 'years', 'failing', 'nytimes', 'others', 'must', 'apologize', 'stock', 'market', 'hits', 'new', 'high', 'longest', 'winning', 'streak', 'decades', 'great', 'level', 'confidence', 'optimism', 'even', 'tax', 'plan', 'rollout', 'venezuela', 'allow', 'leopoldo', 'lopez', 'political', 'prisoner', 'amp', 'husband', 'liliantintori', 'met', 'w', 'marcorubio', 'aetna', 'ceo', 'obamacare', 'death', 'spiral', 'repealandreplace', 'join', 'florida', 'saturday', '5pm', 'rally', 'orlandomelbourne', 'international', 'airporttickets', 'welcome', 'united', 'states', 'israelipm', 'benjamin', 'amp', 'saraicymijoint', 'press', 'conference', 'great', 'listening', 'session', 'ceos', 'retail', 'industry', 'leaders', 'association', 'morning', 'real', 'scandal', 'classified', 'information', 'illegally', 'given', '``', 'intelligence', "''", 'like', 'candy', 'unamerican', 'crimea', 'taken', 'russia', 'obama', 'administration', 'obama', 'soft', 'russia', 'thank', 'eli', 'lake', 'bloomberg', 'view', '``', 'nsa', 'amp', 'fbishould', 'interfere', 'politicsand', "''", 'serious', 'situation', 'usa', 'information', 'illegally', 'given', 'failing', 'nytimes', 'amp', 'washingtonpost', 'intelligence', 'community', 'nsa', 'fbijust', 'like', 'russia', 'russian', 'connection', 'nonsense', 'merely', 'attempt', 'coverup', 'many', 'mistakes', 'made', 'hillary', 'clintons', 'losing', 'ca ...

# %%
bo_words = unidecode( ' '.join(barack_df["text"].values))
bo_words = re.sub(r"http\S+", "", bo_words)
bo_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", bo_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(bo_corpus.lower())
bo_filtered_text = [w for w in word_tokens if not w in stop_words]
print(bo_filtered_text)
# Out:
# ['asked', 'answered', 'happy', 'valentines', 'day', 'michelleobama', 'almost', '28', 'years', 'always', 'feels', 'new', 'read', 'letters', 'like', 'every', 'single', 'day', 'one', 'best', 'parts', 'job', 'hearing', 'rt', 'obamafoundation', 'add', 'voice', 'meantime', 'want', 'hear', 'youre', 'thinking', 'road', 'ahead', 'share', 'ideas', 'hi', 'everybody', 'back', 'original', 'handle', 'thing', 'still', 'michelle', 'quick', 'vacation', 'well', 'get', 'back', 'work', 'tonight', 'president', 'obama', 'reflects', 'eight', 'years', 'progress', 'watch', 'farewelladdress', '9', 'pm', 'et', 'obamafarewell', 'rt', 'ofa', '``', 'thanks', 'affordable', 'care', 'act', 'coverage', 'better', 'today', "''", 'watch', 'weekly', 'address', 'weekly', 'address', 'president', 'obama', 'discusses', 'obamacare', 'done', 'improve', 'health', 'care', 'lets', 'keep', 'working', 'keep', 'economy', 'better', 'stronger', 'course', 'landmark', 'parisagreement', 'enters', 'force', 'todaywe', 'must', 'keep', 'momentum', 'actonclimate', 'economy', 'added', '161000', 'jobs', 'october', 'wages', '28', 'percent', 'past', 'year', 'jobsreport', 'lot', 'plans', 'check', 'options', 'lock', 'one', 'thats', 'best', 'getcovered', 'positive', 'impact', 'obamacare', 'undeniable', 'theres', 'one', 'big', 'factor', 'holding', 'many', 'states', 'back', 'rt', 'potus', 'happened', 'cubs', 'win', 'world', 'series', 'thats', 'change', 'even', 'south', 'sider', 'believe', 'want', 'come', 'white', 'house', 'tens', 'millions', 'americans', 'benefited', 'obamacare', 'make', 'sure', 'youre', 'one', 'getcovered', 'thanks', 'obamacare', 'quality', 'health', 'care', 'available', 'everyone', 'marketplace', 'openmake', 'sure', 'rt', 'lacasablanca', 'la', 'tipica', 'latina', 'tarda', '22', 'meses', 'en', 'ganar', 'lo', 'que', 'un', 'hombre', 'blanco', 'gana', 'en', '12', 'meses', 'tenemos', 'que', 'cerrar', 'la', 'brecha', 'salarial', 'rt', 'whitehouse', 'latinaequalpay', 'day', 'mark', 'work', 'remains', 'ensure', 'americans', 'receive', 'equal', 'pay', 'equal', 'work', 'community', 'organizing', 'never', 'goes', 'style', 'shop', 'obamacare', 'people', 'focus', 'treatment', 'preexisting', 'conditions', 'without', 'fear', 'coverage', 'cappe', 'obamacare', 'marketplace', 'open', 'youre', 'uninsured', 'time', 'shop', 'plan', 'getcovered', 'rt', 'flotus', 'open', 'enrollment', 'starts', 'tomorrow', 'check', 'options', 'share', 'getcovered', 'story', 'lions', 'tiggers', 'bears', 'oh', 'happyhalloween', 'usted', 'su', 'familia', 'merecen', 'la', 'tranquilidad', 'de', 'saber', 'que', 'estan', 'cubiertos', 'el', 'mercado', 'de', 'seguros', 'abre', 'manana', 'speak', 'support', 'quality', 'affordable', 'health', 'care', 'theres', 'nothing', 'scared', 'searching', 'health', 'insurance', 'three', 'four', 'people', 'getcovered', 'less', 'open', 'enrollment', 'begins', 'tomorrowmake', 'sure', 'loved', 'ones', 'getcovered', 'rt', 'ofa', 'witch', 'plan', 'best', 'thanks', 'obamacare', 'even', 'preexisting', 'conditions', 'cant', 'stop', 'comparing', 'options', 'getcove', 'senate', 'leaders', 'obstruction', 'supreme', 'court', 'nomination', 'process', 'unacceptable', 'say', 'doyourjob', 'senate', 'leaders', 'put', 'common', 'good', 'politicsthe', 'integrity', 'nations', 'highest', 'court', 'depends', 'dont', 'ghost', 'health', 'wellbeingyour', 'chance', 'getcovered', 'coming', 'open', 'enrollment', 'starts', 'november', 'climate', 'change', 'happening', 'denial', 'dangerous', 'youre', 'willing', 'work', 'hard', 'play', 'rules', 'able', 'get', 'ahead', 'president', 'obama', 'lays', 'ways', 'obamacare', 'helped', 'millions', 'americans', 'new', 'report', 'renewable', 'energy', 'installations', 'beating', 'fossil', 'fuel', 'installations', 'first', 'time', 'actonclimate', 'obamacare', 'helped', 'millions', 'americans', 'gain', 'peace', 'mind', 'comes', 'coverage', 'show', 'support', 'happens', 'focus', 'building', 'economy', 'works', 'everyone', 'top', 'ones', 'wrapped', 'preexisting', 'conditions', 'getc ...

# %%
mm_words = unidecode( ' '.join(michael_df["text"].values))
mm_words = re.sub(r"http\S+", "", mm_words)
mm_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", mm_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(mm_corpus.lower())
mm_filtered_text = [w for w in word_tokens if not w in stop_words]
print(mm_filtered_text)
# Out:
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/unidecode/__init__.py:50: RuntimeWarning: Surrogate character u'\ude47' will be ignored. You might be using a narrow Python build.
#   return _unidecode(string)
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/unidecode/__init__.py:50: RuntimeWarning: Surrogate character u'\udfb5' will be ignored. You might be using a narrow Python build.
#   return _unidecode(string)
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/unidecode/__init__.py:50: RuntimeWarning: Surrogate character u'\udcdd' will be ignored. You might be using a narrow Python build.
#   return _unidecode(string)
# ['rt', 'cgreensit', 'barackobama', 'obamacare', 'cobra', 'right', 'chris', 'hayes', 'tonight', '845pm', 'et', 'msnbc', 'discuss', 'incredible', 'resistance', 'taking', 'place', 'across', 'country', 'amp', 'u', 'join', '10', 'things', 'trump', 'toast', 'michael', 'moore', 'rt', 'tmorello', 'check', 'upcoming', 'actions', 'everywhere', 'rt', 'belindaofficial', 'brilliant', 'ive', 'joined', 'resist', 'rt', 'nycjim', 'awesome', 'work', 'washpost', 'fact', 'checker', 'tracking', '132', 'false', 'misleading', 'claims', 'president', 'trump', 'far', 'rt', 'repbarbaralee', 'ive', 'introduced', 'bill', 'make', 'congress', 'vote', 'steve', 'bannons', 'nsc', 'role', 'influence', 'trump', 'admin', 'concern', 'michael', 'moore', 'wants', 'help', 'find', 'next', 'antitrump', 'protest', 'via', 'huffpostimpact', 'rt', 'resistcalendar', 'organize', 'resist', 'repeat', 'incredible', 'turnouts', 'congressional', 'town', 'hall', 'meetings', 'across', 'country', 'congrats', '2', 'amp', 'keep', 'find', '1', 'near', 'u', 'read', 'new', 'post', '``', 'ten', 'things', 'trump', 'toast', "''", '10point', 'action', 'plan', 'stop', 'realdonaldtrump', 'im', 'part', 'resistance', 'calendar', 'free', 'daily', 'listing', 'actions', '2', 'stop', 'trump', 'near', 'u', 'minutes', 'ago', 'launched', 'resistance', 'calendar', 'onestop', 'site', 'antitrump', 'actions', 'every', 'day', 'nationwide', 'half', 'go', 'graves', 'always', 'believing', 'sweden', '911', 'last', 'friday', 'night', 'nothing', 'w', 'part', 'trumps', 'genius', 'w', 'half', 'followersll', 'say', '``', 'named', 'wrong', 'countrybut', 'point', 'correc', 'every', 'time', 'trump', 'speaks', 'networks', 'papers', 'obligated', 'immediate', 'segment', 'called', '``', 'orwell', 'file', "''", 'nyc', 'today', 'sunday', 'noon', 'rt', 'marinagipps', 'fakepresidentsday', 'crew', 'inside', 'nuremberg', 'florida', '50000', 'rabid', 'trump', 'faithful', 'shown', 'get', 'reelect', 'trump', '2020', 'rally', 'massive', 'turnout', 'hangar', 'holds', '10k', 'jammed', 'trump', 'wants', '2', 'president', 'til', 'jan', '2025', 'hell', 'nearly', '80', 'way', 'saying', 'president', 'life', '1000yr', 'reich', 'life', 'trump', 'rally', 'right', 'fl', '``', 'official', 'reelect', 'trump', '2020', 'campaign', 'rally', "''", 'sponsored', 'paid', '``', 'reelect', 'trump', '2020', "''", 'job', 'opening', 'theater', 'manager', 'nonprofit', 'movie', 'theater', 'ive', 'restored', 'amp', 'run', 'michigan', 'info', 'amp', 'apply', 'fakepresidentsdayweekend', 'agree', 'donald', 'mess', 'obama', 'respect', 'love', 'decency', 'diversity', 'knowing', 'th', 'call', 'senators', 'morning', 'tell', 'must', 'vote', 'today', 'scott', 'pruitt', 'head', 'epa', '2022253121', 'ill', 'give', 'performance', 'artist', 'known', 'trump', 'base', '60m', 'ppl', 'nation', '325m', 'loved', 'every', 'minute', 'whacked', 'show', 'today', 'watch', 'force', 'quit', 'job', 'amp', 'devote', 'every', 'day', 'removing', 'lunatic', 'office', 'seriously', '12', 'hrs', 'ago', 'amp', 'cant', 'get', '2', 'sleep', 'alone', 'whole', 'country', 'hard', 'time', 'sleeping', 'tonight', 'never', 'unable', '2', 'fall', 'asleep', 'simply', 'watching', 'press', 'conference', 'disturbing', 'thing', 'ive', 'ever', 'seen', 'ontv', 'wow', 'navy', 'seal', 'thinks', 'trump', 'administration', 'messy', 'dangerous', 'join', 'support', 'rally', 'please', 'attend', 'new', 'york', 'area', 'tell', 'ur', 'senators', 'amphouse', 'members', 'u', 'want', 'em', '2', 'cease', 'business', 'til', 'appoint', 'special', 'committee', 'trump', 'amp', 'russians', '2022253121', 'breaking', 'shocking', 'intel', 'agencies', 'afraid', 'trump', 'may', 'betray', 'us', 'withhold', 'intel', 'congress', 'must', 'cease', 'actions', 'wednesday', 'today', 'defend', 'immigrants', 'second', 'night', 'row', 'stephen', 'colbert', 'used', '``', "''", 'word', 'air', 'afraid', 'say', 'treason', 'trumps', 'labor', 'secretary', 'nominee', 'facing', 'certain', 'defeat', 'senate', '4', 'republican', 'senators', 'possibly', 'v ...

# %%
ow_words = unidecode( ' '.join(oprah_df["text"].values))
ow_words = re.sub(r"http\S+", "", ow_words)
ow_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", ow_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize
', 'trade', 'earrings', 'theyre', 'big', 'enough', 'wire', 'account', 'queensugar', 'thats', 'hit', 'every', 'nerve', 'realtalk', 'queensugar', '``', 'youll', 'never', 'another', '``', 'bam', 'queensugar', 'made', 'lol', 'glad', 'remy', 'told', 'respect', 'queensugar', 'rt', 'owntvfans', '5', 'minutes', 'queensugar', 'season', 'finale', 'owntv', 'towingaevans', 'great', 'first', 'class', 'yesterday', 'richonown', 'ava', 'owntv', 'agree', 'rich', 'rt', 'richonown', 'oprah', 'ava', 'queensugar', 'everything', 'owntv', 'meant', '3lwtv', 'tpoulos', 'yep', 'didnt', 'want', 'miss', 'twitter', 'gif', 'fun', 'fest', 'ava', 'would', 'queensugarfinale', 'didnt', 'know', '2nd', 'season', 'coming', 'thanks', 'profoundly', 'great', 'directhers', 'tpoulos', 'ready', 'made', 'chai', 'tweet', 'ready', 'gimmesugar', 'queensugarfinale', 'alright', 'sweeties', 'leading', 'tonight', 'go', 'queensugar', 'finale', 'whos', 'watching', 'rt', 'queensugarown', 'charley', 'find', 'decisions', 'consequences', 'tunein', 'tonight', 'allnew', 'queensugar', 'fun', 'iamsteveharvey', 'gave', 't ...

# %%
em_words = unidecode( ' '.join(elon_df["text"].values))
em_words = re.sub(r"http\S+", "", em_words)
em_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'',']", "", em_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(em_corpus.lower())
em_filtered_text = [w for w in word_tokens if not w in stop_words]
print(em_filtered_text)
# Out:
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/unidecode/__init__.py:50: RuntimeWarning: Surrogate character u'\ude80' will be ignored. You might be using a narrow Python build.
#   return _unidecode(string)
# ['posted', 'video', 'baby', 'came', 'back', 'rt', 'spacex', 'falcon', '9', 'first', 'stage', 'landed', 'lz1', 'mattnewby', 'rt', 'nasa', 'right', 'schedule', 'solar', 'arrays', 'deployed', 'spacex', 'dragon', 'cargo', 'spacecraft', 'watch', 'xuan_thai', 'system', 'green', 'launch', 'called', 'spacecom', 'often', 'right', 'case', 'already', 'retired', 'much', 'rampd', 'risk', 'dragon', '2', 'feel', 'confident', '2018', 'zperrin99', 'uses', 'high', 'pressure', 'bleed', 'fuel', 'side', 'rp1', 'kerosene', 'turbopump', 'dedicated', 'pump', 'fluid', 'needed', 'btw', '99', 'likely', 'fine', 'closed', 'loop', 'tvc', 'wd', 'overcome', 'error', '1', 'chance', 'isnt', 'worth', 'rolling', 'dice', 'better', 'wait', 'day', 'zybbby', 'obviously', 'related', 'tiny', 'helium', 'leak', 'also', 'question', 'issue', 'flight', 'would', 'fine', 'need', 'make', 'sure', 'isnt', 'symptomatic', 'significant', 'upstream', 'root', 'cause', 'systems', 'go', 'except', 'movement', 'trace', 'upper', 'stage', 'engine', 'steering', 'hydraulic', 'piston', 'slightly', 'odd', 'standing', 'investigate', 'rt', 'spacex', '1', 'hour', 'launch', 'falcon', '9', 'amp', 'dragon', 'space_station', 'rocket', 'amp', 'weather', 'go', 'launch', '1001am', 'et', '1501', 'utc', 'counting', 'first', 'spacex', 'launch', 'apollo', '11', 'launch', 'pad', 'tomorrow', 'morning', 'webcast', 'rt', 'nasa', 'hear', 'experts', '5pm', 'et', 'status', 'tomorrows', '1001am', 'et', 'spacex', 'cargo', 'launch', 'space_station', 'spacexs', 'photo', 'provided', 'dragon', '2', 'demo', 'missions', 'go', 'well', 'spacex', 'highly', 'confident', 'able', 'fly', 'us', 'astronauts', '2018', 'looks', 'like', 'go', 'launch', 'added', 'abort', 'trigger', 't60', 'secs', 'pressure', 'decay', 'upper', 'stage', 'helium', 'spin', 'start', 'system', 'investigating', 'small', 'leak', 'upper', 'stage', 'ok', 'launch', 'tomorrow', 'emenietti', 'chafkin', 'yes', 'deep', 'solid', 'rock', 'walls', 'selfsupporting', 'concrete', 'reinforcements', 'arguably', 'arent', 'needed', 'sc00bs', 'much', 'easier', 'cgi', 'way', 'daylight', 'rocket', 'launch', 'amp', 'landing', 'cape', 'weekend', '1st', 'spacex', 'flight', 'apollo', 'launch', 'pad', 'phoebecoleman', 'used', 'one', 'ok', 'good', 'ones', 'meter', 'hopefully', 'kids', 'cant', 'die', 'groaning', 'much', 'vrgtech', 'floydilicious', 'india', 'proud', 'osiris26', 'may', 'come', 'regret', 'request', 'littledovah', 'yeah', 'exactly', 'makes', 'cool', 'right', 'floydilicious', 'yeah', 'awesome', 'achievement', 'isro', 'impressive', 'apparently', 'thing', 'called', '``', 'dad', 'jokes', "''", 'make', 'ludwigmorelos', 'youre', 'right', 'cant', 'hide', 'irony', 'man', 'samcornwell', 'earlier', 'drafts', 'accidentally', 'published', 'said', 'thing', 'week', 'already', 'appreciation', 'tesla', 'providing', 'repair', 'costs', 'free', 'charge', 'expedited', 'congrats', 'tesla', 'owner', 'sacrificed', 'damage', 'car', 'bring', 'car', 'unconscious', 'driver', 'safely', 'stop', 'lollieshopmom', 'best', 'place', 'watch', 'cape', 'causeway', 'seacitylight', 'nas2four', 'sounds', 'like', 'tesla', 'powerwall', 'consumer', 'powerpack', 'utilitycommercial', 'might', 'useful', 'falcon', '9', 'rocket', 'vertical', 'cape', 'canaveral', 'launch', 'complex', '39a', 'launch', 'accohen', 'megangeuss', 'arstechnica', 'exactly', 'person', 'said', 'untrue', 'rusulalrubail', 'markruffalo', 'guardian', 'please', 'check', 'facts', 'tesla', 'spacex', 'joined', 'soon', 'received', 'filing', 'monday', 'rt', 'teslamotors', 'supercharger', 'availability', 'displayed', 'tesla', 'touchscreen', 'see', 'many', 'stalls', 'open', 'ar', 'dknisely', 'course', 'sundalj', 'uploaded', 'next', 'month', 'sureal808', 'motor', 'trend', 'could', 'achieve', '24', 'sec', 'tested', 'porsche', '918', 'voltzcoreaudio', 'dont', 'know', 'make', 'think', 'thats', 'rocket', 'completely', 'covered', 'tarpaulin', 'rt', 'spacex', 'targeting', 'feb', '18', 'dragons', 'next', 'resupply', 'mission', 'space_station', '1st', 'launch', 'lc3 ...

# %%
kk_words = unidecode( ' '.join(kim_df["text"].values))
kk_words = re.sub(r"http\S+", "", kk_words)
kk_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'','', ']", "", kk_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(kk_corpus.lower())
kk_filtered_text = [w for w in word_tokens if not w in stop_words]
print(kk_filtered_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-ba6d499a2a9b> in <module>()
#       3 kk_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'','', ']", "", kk_words)
#       4 stop_words = set(stopwords.words('english'))
# ----> 5 word_tokens = word_tokenize(kk_corpus.lower())
#       6 kk_filtered_text = [w for w in word_tokens if not w in stop_words]
#       7 print(kk_filtered_text)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in word_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     return [token for sent in sent_tokenize(text, language)
#     107             for token in _treebank_word_tokenize(sent)]
#     108
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in sent_tokenize(text, language)
#      89     """
#      90     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 91     return tokenizer.tokenize(text)
#      92
#      93 # Standard word tokenizer.
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _slices_from_text(self, text)
#    1276     def _slices_from_text(self, text):
#    1277         last_break = 0
# -> 1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
#    1280             if self.text_contains_sentbreak(context):
#
# KeyboardInterrupt:

# %%
kp_words = unidecode( ' '.join(katy_df["text"].values))
kp_words = re.sub(r"http\S+", "", kp_words)
kp_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'','', ']", "", kp_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(kp_corpus.lower())
kp_filtered_text = [w for w in word_tokens if not w in stop_words]
print(kp_filtered_text)
# Out:
# ['..._ukthefirstvideofromkatyperryspurposefulpoperahasarrivedwatchchainedtotherhythmftskipmarleynowrtkatysprismlightkatyperrymyfavouritemomentinthisvideorealisationmyprotectorrtvoguemagazinewatchkatyperrysnewmusicvideofor', "''", 'chainedtotherhythm', "''", 'omgamicoolyetalmostabsurdwelcometoobliviawhereeverythingisalwaysrosydirectedbymathewcullenftcomingwithinhourswhispers', "''", 'action', "''", 'ifyoureallylovedmeitwouldbe', "''", 'iloveyoutoplutoandback', "''", 'moonissobasicccnicomizthiswasclassicmiamorettichainedtotherhythmvideotomorrow22117adriana_franc0itsokitsasecondlistenrealizationgirldoyoupaynomindtolehatersguyswhenwillubelievemeforonceidontlieidontevenexaggeratelolyallaremyinspoyougetitgetvalidatedonlovemevideotuesday22117chainedtotherhythmchainedtotherhythmvideotuesday22117', '[', ']', 'chainedtotherhythmvideotuesday22117', '[', ']', 'itsallcomingtogetherbabyeagleeyesrtawkwardayaalittlegetitlittlebehindthescenesfrommakingthechainedtotherhythmlyricvidkatysredskittleshesbackrttiedye_princesskatyperryjustlaunchedhernewshoecollectionimdownrtadelshahalkatyperrymy3yearoldhasbeensingingyoursongdailyactuallythissonghasbeenplayinginmyhouseholddailysincetrtocgaykatyperrylatelyjosephn94isthatnarrationbygeorgetakeiadmissionis', "''", 'free', "''", '...', '[', ']', 'rtmarinadiamandis', "''", 'untilyoumaketheunconsciousconsciousitwilldirectyourlifeandyouwillcallitfate', "''", 'carljungokyourehirednowtoofabuyouremyfavoritepersonintheworldrnalsowannacomeworkwithme', '[', ']', 'mysoleisready', '[', ']', 'iheartyoucantwaittoseeyouatthetopoftheshow', '[', ']', 'areyoustill', '[', ']', '', "''", 'persist', "''", '...', "''", 'anyonefromanywherecandoanything', "''", '_myricktodayisallaboutyousofifiididyousweatoutallyourcomplacencyicantwaittogiveyouguysmorethankyouallforyourpatienceanddedicationalltheseyearsourabilitytoaccessorizeiswhatseparatesusfromtheanimalshavefundecoratingphotosbyoliviab33martn_acosta12thatisdeepandiloveittheresbeenalotof', "''", 'neverthoughts', "''", '', '[', ']', 'foryourfreakingweekend', '[', ']', '..._slaysmrparsonswasinspiredbythebook1984canyouconfirmthiskatyperrykatycatayleen2youllsee_', '[', ']', '[', ']', 'illalwaysmarchwithyousisterpopthatbischjohnlordperryohtheyretheretheygetgarnishedandallevolutionrightontrackquestioneverythingwegonnacallthiserapurposefulpopdivedeeperintothisbopfeastyoureyesonthelyrics', '[', ']', 'chainedtotherhythmnowavailableeverywhere', '[', ']', 'andchainedtotherhythmin5minutesonehouruntilchainedtotherhythmcoverartbyfrederikheymanthereyouarertkatylovem5aaaaaaahwearethepowerkatyperrychainedtotherhythmrtbrunastrait_imsoproudofmymomkatyperrychainedtotherhythmwewerewaitingthisbabyballfor5hshannonflynn2nowaaaayrtanafalquetonoinstagrampessoalmentechainedtotherhythmkatyperrymark_hodson_hiyougotdemmilesbabes', '[', ']', '..._flutechainedtotherhythmchicagokatyperryits ...

# %%
nc_words = unidecode( ' '.join(noam_df["text"].values))
nc_words = re.sub(r"http\S+", "", nc_words)
nc_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'','', ']", "", nc_words)
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(nc_corpus.lower())
nc_filtered_text = [w for w in word_tokens if not w in stop_words]
print(nc_filtered_text)
# Out:
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/unidecode/__init__.py:50: RuntimeWarning: Surrogate character u'\udcf9' will be ignored. You might be using a narrow Python build.
#   return _unidecode(string)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-af3a1839a109> in <module>()
#       3 nc_corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>'','', ']", "", nc_words)
#       4 stop_words = set(stopwords.words('english'))
# ----> 5 word_tokens = word_tokenize(nc_corpus.lower())
#       6 nc_filtered_text = [w for w in word_tokens if not w in stop_words]
#       7 print(nc_filtered_text)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in word_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     return [token for sent in sent_tokenize(text, language)
#     107             for token in _treebank_word_tokenize(sent)]
#     108
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in sent_tokenize(text, language)
#      89     """
#      90     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 91     return tokenizer.tokenize(text)
#      92
#      93 # Standard word tokenizer.
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _slices_from_text(self, text)
#    1276     def _slices_from_text(self, text):
#    1277         last_break = 0
# -> 1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
#    1280             if self.text_contains_sentbreak(context):
#
# KeyboardInterrupt:

# %%
def cleaned_text(X):
    all_words = [rb_words, gr_words, dt_words, bo_words, mm_words, ow_words, em_words, kk_words, kp_words, nc_words]
    words = X.replace('\(', '').replace('\)', '').replace('@', '').replace('https://.?', '')
    words = re.sub(r"http\S+", "", words)
    corpus = re.sub("['\''%'':''#'')''('';''\n''/''.''!''*''-''+''$'',''?''~''&''@''``''-''=''--''|''<''>']", "", words)
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(corpus.lower())
    filtered_text = [w for w in word_tokens if not w in stop_words]
    for p in all_words:
        return {p: filtered_text}

# %%
cleaned_text(rb_words)

# %%
with open('pc_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(pc_filtered_text, picklefile)

# %%
with open('bo_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(bo_filtered_text, picklefile)

# %%
with open('ow_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(ow_filtered_text, picklefile)

# %%
with open('em_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(em_filtered_text, picklefile)

# %%
with open('mm_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(mm_filtered_text, picklefile)

# %%
with open('dt_filtered_text', 'w') as picklefile:
    pickle.dump(dt_filtered_text, picklefile)

# %%
with open('kp_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(kp_filtered_text, picklefile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-00c5d63f7689> in <module>()
#       1 with open('kp_filtered_text.pkl', 'w') as picklefile:
# ----> 2     pickle.dump(kp_filtered_text, picklefile)
#
# NameError: name 'kp_filtered_text' is not defined

# %%
with open('gr_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(gr_filtered_text, picklefile)

# %%
with open('nc_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(nc_filtered_text, picklefile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a39cf5db568d> in <module>()
#       1 with open('nc_filtered_text.pkl', 'w') as picklefile:
# ----> 2     pickle.dump(nc_filtered_text, picklefile)
#
# NameError: name 'nc_filtered_text' is not defined

# %%
with open('rb_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(rb_filtered_text, picklefile)

# %%
with open('kk_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(kk_filtered_text, picklefile)

# %%
with open('ed_filtered_text.pkl', 'w') as picklefile:
    pickle.dump(ed_filtered_text, picklefile)

# %%
with open('tweets_df.pkl', 'w') as picklefile:
    pickle.dump(tweets_df, picklefile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-2e8f96d3c9a3> in <module>()
#       1 with open('tweets_df.pkl', 'w') as picklefile:
# ----> 2     pickle.dump(tweets_df, picklefile)
#
# NameError: name 'tweets_df' is not defined
