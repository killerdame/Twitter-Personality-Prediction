# %%
# preliminaries
from pymongo import MongoClient
from nltk.corpus import stopwords
from string import ascii_lowercase
import pandas as pimport, gensim, os, re, pymongo, itertools, nltk, snowballstemmer
from collections import Counter

# %%
data = pd.read_pickle('tweets_df.pkl')

# %%
data.head(20)
# Out:
#                                                  text      user
# 0         Just posted a video https://t.co/RCV7MVi8rs  elonmusk
# 1                             https://t.co/6Ve3YJoStm  elonmusk
# 2              Baby came back https://t.co/5FRhw3AT2b  elonmusk
# 3   RT @SpaceX: Falcon 9 first stage has landed at...  elonmusk
# 4                                       @mattnewby no  elonmusk
# 5   RT @NASA: Right on schedule, solar arrays have...  elonmusk
# 6   @Xuan_Thai System was green for launch. I call...  elonmusk
# 7   @spacecom They are often right, but, in this c...  elonmusk
# 8   @zperrin99 Uses high pressure bleed off the fu...  elonmusk
# 9   Btw, 99% likely to be fine (closed loop TVC wd...  elonmusk
# 10  @Zybbby Not obviously related to the (very tin...  elonmusk
# 11  If this is the only issue, flight would be fin...  elonmusk
# 12  All systems go, except the movement trace of a...  elonmusk
# 13  RT @SpaceX: 1 hour from launch of Falcon 9 &am...  elonmusk
# 14  Counting down to the first SpaceX launch from ...  elonmusk
# 15  RT @NASA: Hear from experts at 5pm ET about th...  elonmusk
# 16             spacex's photo https://t.co/ImEDAut3nI  elonmusk
# 17  Provided Dragon 2 demo missions go well, Space...  elonmusk
# 18  Looks like we are go for launch. Added an abor...  elonmusk
# 19  Investigating a (very small) leak in the upper...  elonmusk

# %%
# # set the location where we'll save our model
# savefolder = 

# # grab data from database and convert to pandas dataframe
# client = MongoClient()
# db = client.target_database # access target database
# collection = db.target_collection # access target collection within the target database
# data = pd.DataFrame(list(collection.find())) # each row is one document; the raw text of the document should be in the 'text_data' column

data = pd.read_pickle('tweets_df.pkl')

# initialize stemmer
# stemmer = snowballstemmer.EnglishStemmer()

# grab stopword list, extend it a bit, and then turn it into a set for later
stop = stopwords.words('english')
# stop.extend(['may','also','one','two','three','four','five','six','seven','eight','nine','ten','across','among','beside','however','yet','within']+list(ascii_lowercase))
# stoplist = stemmer.stemWords(stop)
# stoplist = set(stoplist)
# stop = set(sorted(stop + list(stoplist))) 

# remove characters and stoplist words, then generate dictionary of unique words
data['text'].replace("http\S+",' ',inplace=True,regex=True)
data['text'].replace('[!"$#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ',inplace=True,regex=True)
wordlist = filter(None, " ".join(list(set(list(itertools.chain(*data['text'].str.split(' ')))))).split(" "))
data['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in stop, line))) for line in data['text'].str.lower().str.split(' ')]

# remove all words that don't occur at least 5 times and then stem the resulting docs
minimum_count = 5
str_frequencies = pd.DataFrame(list(Counter(filter(None,list(itertools.chain(*data['stemmed_text_data'].str.split(' '))))).items()),columns=['word','count'])
low_frequency_words = set(str_frequencies[str_frequencies['count'] < minimum_count]['word'])
data['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in low_frequency_words, line))) for line in data['stemmed_text_data'].str.split(' ')]
data['stemmed_text_data'] = [" ".join(stemmer.stemWords(re.sub('[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ', next_text).split(' '))) for next_text in data['stemmed_text_data']]

# run word2vec model and then save it
texts_stemmed = filter(None, [next_text.strip(' ').split(' ') for next_text in data['stemmed_text_data']])
w2vmodel_stemmed = gensim.models.Word2Vec(texts_stemmed, size=100, window=5, min_count=5, workers=4)
finished = w2vmodel_stemmed.save('w2v_stemmed_model')

# %%
cleaned_data = data.drop(['text'], axis= 1)

# %%
cleaned_data.rename(columns = {'stemmed_text_data':'text'}, inplace = True)

# %%
cleaned_data
# Out:
#              user                                               text
# 0        elonmusk                                         post video
# 1        elonmusk
# 2        elonmusk                                     babi came back
# 3        elonmusk               rt spacex falcon first stage land lz
# 4        elonmusk
# 5        elonmusk  rt nasa right schedul solar deploy spacex drag...
# 6        elonmusk                           system green launch call
# 7        elonmusk  often right case alreadi retir much risk drago...
# 8        elonmusk   use high pressur fuel side dedic pump fluid need
# 9        elonmusk  btw like fine close loop wd overcom chanc wort...
# 10       elonmusk       obvious relat tini helium leak also question
# 11       elonmusk  issu flight would fine need make sure signific...
# 12       elonmusk  system go except movement upper stage engin st...
# 13       elonmusk  rt spacex hour launch falcon &amp dragon space...
# 14       elonmusk  count first spacex launch apollo launch pad to...
# 15       elonmusk  rt nasa hear expert pm et status tomorrow et s...
# 16       elonmusk                                       spacex photo
# 17       elonmusk  provid dragon demo mission go well spacex high...
# 18       elonmusk  look like go launch ad abort pressur upper sta...
# 19       elonmusk          small leak upper stage ok launch tomorrow
# 20       elonmusk         yes deep solid rock wall self support need
# 21       elonmusk                              sc bs much easier way
# 22       elonmusk  rocket launch &amp land cape weekend st spacex...
# 23       elonmusk                                            use one
# 24       elonmusk                      ok good one hope kid die much
# 25       elonmusk                                        india proud
# 26       elonmusk                            may come regret request
# 27       elonmusk                         yeah exact make cool right
# 28       elonmusk                         yeah awesom achiev impress
# 29       elonmusk                     appar thing call dad joke make
# ...           ...                                                ...
# 3210  BarackObama  watch climat chang averag u season longer inte...
# 3211  BarackObama                       hour enough time raisethewag
# 3212  BarackObama  studi state obamacar see biggest drop uninsur wsj
# 3213  BarackObama     last chanc sign ofa birthday card presid obama
# 3214  BarackObama  forget leav person note presid obama birthday ...
# 3215  BarackObama           peopl prefer cake like pie —presid obama
# 3216  BarackObama      rt vp happi birthday good friend presid obama
# 3217  BarackObama           rt todayshow happi birthday presid obama
# 3218  BarackObama            rt happi birthday mr presid barackobama
# 3219  BarackObama  rt happi birthday presid barackobama ever need...
# 3220  BarackObama  rt flotus happi birthday man alway make proud ...
# 3221  BarackObama  presid obama michell send deepest condol famil...
# 3222  BarackObama                    send presid obama love birthday
# 3223  BarackObama      retweet share happi remind health care reform
# 3224  BarackObama              today presid obama sure sign ofa card
# 3225  BarackObama  help put smile presid face sign ofa birthday card
# 3226  BarackObama  icymi six month row privat sector job creation...
# 3227  BarackObama  hard time pick card luck ofa want pick favorit...
# 3228  BarackObama  sign name ofa birthday card send note thank pr...
# 3229  BarackObama  bottom line we’v come long way past five half ...
# 3230  BarackObama  watch week address presid work help middl clas...
# 3231  BarackObama       sign ofa birthday card presid send best wish
# 3232  BarackObama  fact million privat sector job ad past month a...
# 3233  BarackObama  straight month privat sector job longest strea...
# 3234  BarackObama  overcom congress stop stand way countri succes...
# 3235  BarackObama  fact could much along congress would job peopl...
# 3236  BarackObama  longest streak privat sector job creation hist...
# 3237  BarackObama     happen presid obama deliv statement brief room
# 3238  BarackObama  job growth sixth straight month progress actonjob
# 3239  BarackObama  job growth sixth straight month progress actonjob
#
# [41609 rows x 2 columns]

# %%
with open('cleaned_data.pkl', 'w') as picklefile:
    pickle.dump(cleaned_data, picklefile)

# %%
import pickle
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from nltk.stem import LancasterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# from spacy import

# %%
tweets_df = pd.read_pickle('tweets_df.pkl')

# %%
tweets_df['text'].replace('http\S+',' ',inplace=True,regex=True)

# %%
tweets_df['text'].replace('[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ',inplace=True,regex=True)

# %%
cleaned_tweets_df = tweets_df
cleaned_tweets_df.head()
# Out:
#                                                 text      user
# 0                              Just posted a video    elonmusk
# 1                                                     elonmusk
# 2                                   Baby came back    elonmusk
# 3  RT  SpaceX  Falcon   first stage has landed at...  elonmusk
# 4                                       mattnewby no  elonmusk

# %%
wordlist = filter(None, " ".join(list(set(list(itertools.chain(*data['text_data'].str.split(' ')))))).split(" "))
data['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in stop, line))) for line in data['text_data'].str.lower().str.split(' ')]
