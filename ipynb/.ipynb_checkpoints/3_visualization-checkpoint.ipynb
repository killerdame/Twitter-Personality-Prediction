# %%
import os
os.chdir('../')

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
from lib.visualization import wordcloud_mod

# %%
oprah = pd.read_pickle('data/ow_filtered_text.pkl')
oprah_text = " ".join(oprah)
wordcloud_mod(oprah_text, num_words=50)

# %%
elon = pd.read_pickle('data/em_filtered_text.pkl')
elon = ' '.join(elon)
wordcloud_mod(elon, num_words=30)

# %%
donald = pd.read_pickle('data/dt_filtered_text.pkl')
donald = ' '.join(donald)
wordcloud_mod(donald, num_words=30)

# %%
barack = pd.read_pickle('data/bo_filtered_text.pkl')
barack = ' '.join(barack)
wordcloud_mod(barack, num_words=30)

# %%
michael = pd.read_pickle('data/mm_filtered_text.pkl')
michael = ' '.join(michael)
wordcloud_mod(michael, num_words=30)

# %%
paolo = pd.read_pickle('data/pc_filtered_text.pkl')
paolo = ' '.join(paolo)
wordcloud_mod(paolo, num_words=30)

# %%
ellen = pd.read_pickle('data/ed_filtered_text.pkl')
ellen  = ' '.join(ellen)
wordcloud_mod(ellen, num_words=30)

# %%
russell = pd.read_pickle('data/rb_filtered_text.pkl')
russell = ' '.join(russell)
wordcloud_mod(russell, num_words=30)

# %%
katy = pd.read_pickle('data/kp_filtered_text.pkl')
katy = ' '.join(katy)
wordcloud_mod(katy, num_words=30)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-36-b812452c0c73> in <module>()
# ----> 1 katy = pd.read_pickle('data/kp_filtered_text.pkl')
#       2 katy = ' '.join(katy)
#       3 wordcloud_mod(katy, num_words=30)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      63
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#      67         if PY3:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      60             except:
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#      64     try:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/compat/pickle_compat.pyc in load(fh, encoding, compat, is_verbose)
# ...

# %%
kim = pd.read_pickle('data/kk_filtered_text.pkl')
kim = ' '.join(kim)
wordcloud_mod(kim, num_words=30)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-37-30ed3dca28d7> in <module>()
# ----> 1 kim = pd.read_pickle('data/kk_filtered_text.pkl')
#       2 kim = ' '.join(kim)
#       3 wordcloud_mod(kim, num_words=30)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      63
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#      67         if PY3:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      59             # compat pickle
#      60             except:
# ---> 61                 with open(path, 'rb') as fh:
#      62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#
# IOError: [Errno 2] No such file or directory: 'data/kk_filtered_text.pkl'

# %%
gina = pd.read_pickle('data/gr_filtered_text.pkl')
gina = ' '.join(gina)
wordcloud_mod(gina, num_words=30)

# %%
noam = pd.read_pickle('data/nc_filtered_text.pkl')
noam = ' '.join(noam)
wordcloud_mod(noam, num_words=30)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-38-bedfad8228e7> in <module>()
# ----> 1 noam = pd.read_pickle('data/nc_filtered_text.pkl')
#       2 noam = ' '.join(noam)
#       3 wordcloud_mod(noam, num_words=30)
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      63
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#      67         if PY3:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      60             except:
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#      64     try:
#
# /Users/kdgulko/anaconda/lib/python2.7/site-packages/pandas/compat/pickle_compat.pyc in load(fh, encoding, compat, is_verbose)
# ...
